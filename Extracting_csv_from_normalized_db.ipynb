# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect("normalized.db")
cursor = conn.cursor()

# Check tables
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())
# Out:
# [('Region',), ('Country',), ('Customer',), ('ProductCategory',), ('Product',), ('OrderDetail',)]

# %%
tables = ['Region', 'Country', 'Customer', 'ProductCategory', 'Product', 'OrderDetail']

for table in tables:
    df = pd.read_sql_query(f"SELECT * FROM {table}", conn)
    df.to_csv(f"{table}.csv", index=False)
    print(f"{table}.csv exported successfully!")
# Out:
# Region.csv exported successfully!
# Country.csv exported successfully!
# Customer.csv exported successfully!
# ProductCategory.csv exported successfully!
# Product.csv exported successfully!
# OrderDetail.csv exported successfully!
